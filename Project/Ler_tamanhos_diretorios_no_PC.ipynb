# %%
import os

PATH = "/home/lucas"

# listar os diretirios
content = os.listdir(PATH)
diretory = []

# filtrar o diretorios retirando os arquivos ocultos
for item in content:
    if item[0] != ".":
        diretory.append(item)

# verificar se é um diretorio
for item in diretory:
    if os.path.isdir(os.path.join(PATH, item)):
        print("É diretorios: ", item)
        # verificar se o diretorio tem arquivos
        if os.listdir(os.path.join(PATH, item)):
            print(f"{item} tem arquivos")
            # verificar se o diretorio tem arquivos ocultos
            for file in os.listdir(os.path.join(PATH, item)):
                if file[0] != ".":
                    print(os.path.join(PATH, item, file))
        else:
            print(f"{item} is empty")
# Out:
# /home/lucas/anaconda3/ssl
# /home/lucas/anaconda3/cmake
# /home/lucas/anaconda3/libexec
# /home/lucas/anaconda3/lib
# /home/lucas/anaconda3/licensing
# /home/lucas/anaconda3/resources
# /home/lucas/anaconda3/man
# /home/lucas/anaconda3/mysql-test
# /home/lucas/anaconda3/phrasebooks
# /home/lucas/anaconda3/compiler_compat
# /home/lucas/anaconda3/mysql
# /home/lucas/anaconda3/LICENSE.txt
# /home/lucas/anaconda3/plugins
# /home/lucas/anaconda3/x86_64-conda-linux-gnu
# /home/lucas/anaconda3/translations
# /home/lucas/anaconda3/sbin
# /home/lucas/anaconda3/x86_64-conda_cos7-linux-gnu
# /home/lucas/anaconda3/share
# /home/lucas/anaconda3/qml
# /home/lucas/anaconda3/shell
# /home/lucas/anaconda3/var
# /home/lucas/anaconda3/etc
# /home/lucas/anaconda3/include
# /home/lucas/anaconda3/mkspecs
# /home/lucas/anaconda3/condabin
# /home/lucas/anaconda3/pkgs
# /home/lucas/anaconda3/envs
# /home/lucas/anaconda3/doc
# /home/lucas/anaconda3/bin
# /home/lucas/anaconda3/conda-meta
# ...
